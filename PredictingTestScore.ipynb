# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Python Projects/Machine Learning Projects/PredictingTestScore/test_scores.csv'
df = pd.read_csv(path)
df.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_f9c60_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >math</th>
#       <th class="col_heading level0 col2" >cs</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9c60_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f9c60_row0_col0" class="data row0 col0" >david</td>
#       <td id="T_f9c60_row0_col1" class="data row0 col1" >92</td>
#       <td id="T_f9c60_row0_col2" class="data row0 col2" >98</td>
#     </tr>
#     <tr>
#       <th id="T_f9c60_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f9c60_row1_col0" class="data row1 col0" >laura</td>
#       <td id="T_f9c60_row1_col1" class="data row1 col1" >56</td>
#       <td id="T_f9c60_row1_col2" class="data row1 col2" >68</td>
#     </tr>
#     <tr>
#       <th id="T_f9c60_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f9c60_row2_col0" class="data row2 col0" >sanjay</td>
#       <td id="T_f9c60_row2_col1" class="data row2 col1" >88</td>
#       <td id="T_f9c60_row2_col2" class="data row2 col2" >81</td>
#     </tr>
#     <tr>
#       <th id="T_f9c60_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f9c60_row3_col0" class="data row3 col0" >wei</td>
#       <td id="T_f9c60_row3_col1" class="data row3 col1" >70</td>
#       <td id="T_f9c60_row3_col2" class="data row3 col2" >80</td>
#     </tr>
#     <tr>
#       <th id="T_f9c60_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f9c60_row4_col0" class="data row4 col0" >jeff</td>
#       <td id="T_f9c60_row4_col1" class="data row4 col1" >80</td>
#       <td id="T_f9c60_row4_col2" class="data row4 col2" >83</td>
#     </tr>
#     <tr>
#       <th id="T_f9c60_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f9c60_row5_col0" class="data row5 col0" >aamir</td>
#       <td id="T_f9c60_row5_col1" class="data row5 col1" >49</td>
#       <td id="T_f9c60_row5_col2" class="data row5 col2" >52</td>
#     </tr>
#     <tr>
#       <th id="T_f9c60_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f9c60_row6_col0" class="data row6 col0" >venkat</td>
#       <td id="T_f9c60_row6_col1" class="data row6 col1" >65</td>
#       <td id="T_f9c60_row6_col2" class="data row6 col2" >66</td>
#     </tr>
#     <tr>
#       <th id="T_f9c60_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f9c60_row7_col0" class="data row7 col0" >virat</td>
#       <td id="T_f9c60_row7_col1" class="data row7 col1" >35</td>
#       <td id="T_f9c60_row7_col2" class="data row7 col2" >30</td>
#     </tr>
#     <tr>
#       <th id="T_f9c60_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f9c60_row8_col0" class="data row8 col0" >arthur</td>
#       <td id="T_f9c60_row8_col1" class="data row8 col1" >66</td>
#       <td id="T_f9c60_row8_col2" class="data row8 col2" >68</td>
#     </tr>
#     <tr>
#       <th id="T_f9c60_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f9c60_row9_col0" class="data row9 col0" >paul</td>
#       <td id="T_f9c60_row9_col1" class="data row9 col1" >67</td>
#       <td id="T_f9c60_row9_col2" class="data row9 col2" >73</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.sort_values(by=['math'])
# Out:
#      name  math  cs
# 7   virat    35  30
# 5   aamir    49  52
# 1   laura    56  68
# 6  venkat    65  66
# 8  arthur    66  68
# 9    paul    67  73
# 3     wei    70  80
# 4    jeff    80  83
# 2  sanjay    88  81
# 0   david    92  98

# %%
x = df['math'].to_numpy()
y = df['cs'].to_numpy()
plt.xlabel('math')
plt.ylabel('cs')
plt.plot(x,y, 'ro')

# %%
y.head()
# Out:
# 0    98
# 1    68
# 2    81
# 3    80
# 4    83
# Name: cs, dtype: int64

# %%
print(x)
# Out:
# [92 56 88 70 80 49 65 35 66 67]

# %%
print(y)
# Out:
# [98 68 81 80 83 52 66 30 68 73]

# %%
def gradient_descent(x,y,lr,itr):
  m_curr = b_curr = 0
  n = len(x)

  for i in range(itr):
    y_predicted = m_curr * x + b_curr

    cost = (1/n) * sum([val**2 for val in (y - y_predicted)])

    md = -(2/n) *  sum(x * (y - y_predicted))
    bd = -(2/n) * sum(y - y_predicted)

    m_curr = m_curr - md * lr
    b_curr = b_curr - bd * lr

  plt.plot(x, y_predicted, 'r--')

plt.scatter(x, y)
plt.xlabel('math')
plt.ylabel('cs')
gradient_descent(x,y,0.0001,1000000)
